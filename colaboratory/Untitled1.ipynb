# %%
def primerejemplo(nombre, edad):
  #bloque de creacion de variable
  direccion =input("dame tu direccon: ")
  cp = int(input("dame tu codigo postal: "))
  if cp >= 45000 and cp <=45999:
    print("Esta usted en la delegacion de Toledo.")
    if edad < 12:
      print("tienes el autobus gratis.")
      op = input("¿Quieres solicitarlo?(si/no): ")
      if op == "si":
        print("---------------------------------------")
        print("| Carnet de autobus infantil          |")
        print("| Nombre: "+nombre+ "                 |")
        print("| edad: "+str(edad)+"                 |")
        print("---------------------------------------")
    elif edad < 18:
      print("beber y fumar perjudica a las neuronas ")
    else:
     print("paga moroso cabron ")
  else:
      print("no tengo competencia en su poblacion")
primerejemplo("Peter" , 9 )
# Out:
# dame tu direccon: hola
# dame tu codigo postal: 45003
# Esta usted en la delegacion de Toledo.
# tienes el autobus gratis.
# ¿Quieres solicitarlo?(si/no): si
# ---------------------------------------
# | Carnet de autobus infantil          |
# | Nombre: Peter                 |
# | edad: 9                 |
# ---------------------------------------
